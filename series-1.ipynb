# %%
# pandas 
# !pip install pandas
import pandas as pd

# %% [markdown]
# <p style='color:red'>2 Types of Data</p>
# 1-D Data - Series  <br>
# 2-D Data- DataFrames

# %%
# Series

# %%
ser1= pd.Series([34,22,33,78,98])
ser1
# Out:
# 0    34
# 1    22
# 2    33
# 3    78
# 4    98
# dtype: int64

# %%
ser2= pd.Series([12,23,56,78,99,20], index=['a','b','c','d','e','f'])
ser2
# Out:
# a    12
# b    23
# c    56
# d    78
# e    99
# f    20
# dtype: int64

# %%
l=[45,44,32,21,34]
s=pd.Series(l)

# %%
s
# Out:
# 0    45
# 1    44
# 2    32
# 3    21
# 4    34
# dtype: int64

# %%
s1= pd.Series([i for i in range(20) if i%2==0])

# %%
s1
# Out:
# 0     0
# 1     2
# 2     4
# 3     6
# 4     8
# 5    10
# 6    12
# 7    14
# 8    16
# 9    18
# dtype: int64

# %%
s3= pd.Series([i for i in range(0,5)], index=[i**2 for i in range(0,5)])

# %%
s3
# Out:
# 0     0
# 1     1
# 4     2
# 9     3
# 16    4
# dtype: int64

# %%
s1
# Out:
# 0     0
# 1     2
# 2     4
# 3     6
# 4     8
# 5    10
# 6    12
# 7    14
# 8    16
# 9    18
# dtype: int64

# %%
# head 
s1.head()  # by default first 5
# Out:
# 0    0
# 1    2
# 2    4
# 3    6
# 4    8
# dtype: int64

# %%
# head 
s1.head(3)
# Out:
# 0    0
# 1    2
# 2    4
# dtype: int64

# %%
# tail 
s1.tail(2)
# Out:
# 8    16
# 9    18
# dtype: int64

# %%
s3
# Out:
# 0     0
# 1     1
# 4     2
# 9     3
# 16    4
# dtype: int64

# %%
s3.head(10)
# Out:
# 0     0
# 1     1
# 4     2
# 9     3
# 16    4
# dtype: int64

# %%
s1
# Out:
# 0     0
# 1     2
# 2     4
# 3     6
# 4     8
# 5    10
# 6    12
# 7    14
# 8    16
# 9    18
# dtype: int64

# %%
# Access elements  - [], .(dot)

# %%
s1[:3]
# Out:
# 0    0
# 1    2
# 2    4
# dtype: int64

# %%
s1[3:]
# Out:
# 3     6
# 4     8
# 5    10
# 6    12
# 7    14
# 8    16
# 9    18
# dtype: int64

# %%
s1[5]
# Out:
# 10

# %%
s.5  # error
# Out:
#   Cell In[38], line 1
#     s.5
#      ^
# SyntaxError: invalid syntax

# %%
ser2
# Out:
# a    12
# b    23
# c    56
# d    78
# e    99
# f    20
# dtype: int64

# %%
ser2.a
# Out:
# 12

# %%
ser2.b
# Out:
# 23

# %%
ser2['c']
# Out:
# 56

# %%
ser2['a':'d']
# Out:
# a    12
# b    23
# c    56
# d    78
# dtype: int64

# %%
# loc and iloc

# %%
ser1
# Out:
# 0    34
# 1    22
# 2    33
# 3    78
# 4    98
# dtype: int64

# %%
ser1.loc[1:3]  #labels
# Out:
# 1    22
# 2    33
# 3    78
# dtype: int64

# %%
ser1.iloc[1:3]  # index location
# Out:
# 1    22
# 2    33
# dtype: int64

# %%
ser2.loc['a':'d']
# Out:
# a    12
# b    23
# c    56
# d    78
# dtype: int64

# %%
ser2
# Out:
# a    12
# b    23
# c    56
# d    78
# e    99
# f    20
# dtype: int64

# %%
ser2.iloc[:3]
# Out:
# a    12
# b    23
# c    56
# dtype: int64

# %%
ser1
# Out:
# 0    34
# 1    22
# 2    33
# 3    78
# 4    98
# dtype: int64

# %%
ser1.shape
# Out:
# (5,)

# %%
ser1.max()
# Out:
# 98

# %%
ser1.min()
# Out:
# 22

# %%
ser1.mean()
# Out:
# 53.0
