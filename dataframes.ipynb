# %%
import pandas as pd

# %%
df= pd.DataFrame([11,12,13,14,15])
df
# Out:
#     0
# 0  11
# 1  12
# 2  13
# 3  14
# 4  15

# %%
df1= pd.DataFrame([[12,13,15],[45,67,44]])

# %%
df1
# Out:
#     0   1   2
# 0  12  13  15
# 1  45  67  44

# %%
df=pd.DataFrame({'name':['Komal','Surbhi','Anmol','Rohit'],'class':['btech','Mtech','bca','bba'],'marks':[12,14,15,21]})

# %%
df
# Out:
#      name  class  marks
# 0   Komal  btech     12
# 1  Surbhi  Mtech     14
# 2   Anmol    bca     15
# 3   Rohit    bba     21

# %%
df1=pd.DataFrame({'name':['Komal','Surbhi','Anmol','Rohit'],'class':['btech','Mtech','bca','BBA'],'marks':[12,14,15,21]}, index=['a','b','c','d'])
df1
# Out:
#      name  class  marks
# a   Komal  btech     12
# b  Surbhi  Mtech     14
# c   Anmol    bca     15
# d   Rohit    BBA     21

# %%
df1=pd.DataFrame({'name':['Komal','Surbhi','Anmol','Rohit'],'class':['btech','Mtech','bca','BBA'],'marks':[12,14,15,21]}, index=['a','b','c','d'], columns=['name','class'])
df1
# Out:
#      name  class
# a   Komal  btech
# b  Surbhi  Mtech
# c   Anmol    bca
# d   Rohit    BBA

# %%
df2=pd.DataFrame({'name':['Komal','Surbhi','Anmol','Rohit','Hargun','Jannat'],'class':['btech','Mtech','bca','BBA','Btech','MCA'],'marks':[12,14,15,21,24,16]})
df2
# Out:
#      name  class  marks
# 0   Komal  btech     12
# 1  Surbhi  Mtech     14
# 2   Anmol    bca     15
# 3   Rohit    BBA     21
# 4  Hargun  Btech     24
# 5  Jannat    MCA     16

# %%
df3=pd.DataFrame({'name':['Komal','Surbhi','Anmol','Rohit','Hargun','Jannat'],'class':'Btech','marks':[12,14,15,21,24,16]})
df3
# Out:
#      name  class  marks
# 0   Komal  Btech     12
# 1  Surbhi  Btech     14
# 2   Anmol  Btech     15
# 3   Rohit  Btech     21
# 4  Hargun  Btech     24
# 5  Jannat  Btech     16

# %%
df2.head()
# Out:
#      name  class  marks
# 0   Komal  btech     12
# 1  Surbhi  Mtech     14
# 2   Anmol    bca     15
# 3   Rohit    BBA     21
# 4  Hargun  Btech     24

# %%
df2.tail()
# Out:
#      name  class  marks
# 1  Surbhi  Mtech     14
# 2   Anmol    bca     15
# 3   Rohit    BBA     21
# 4  Hargun  Btech     24
# 5  Jannat    MCA     16

# %%
df2['name']
# Out:
# 0     Komal
# 1    Surbhi
# 2     Anmol
# 3     Rohit
# 4    Hargun
# 5    Jannat
# Name: name, dtype: object

# %%
df2[['name','class']]
# Out:
#      name  class
# 0   Komal  btech
# 1  Surbhi  Mtech
# 2   Anmol    bca
# 3   Rohit    BBA
# 4  Hargun  Btech
# 5  Jannat    MCA

# %%
df2.marks
# Out:
# 0    12
# 1    14
# 2    15
# 3    21
# 4    24
# 5    16
# Name: marks, dtype: int64

# %%
df2['name'][:2]
# Out:
# 0     Komal
# 1    Surbhi
# Name: name, dtype: object

# %%
df2['marks'][3]
# Out:
# 21

# %%
#conditions

# %%
df2
# Out:
#      name  class  marks
# 0   Komal  btech     12
# 1  Surbhi  Mtech     14
# 2   Anmol    bca     15
# 3   Rohit    BBA     21
# 4  Hargun  Btech     24
# 5  Jannat    MCA     16

# %%
df2[df2['name']=='Hargun']
# Out:
#      name  class  marks
# 4  Hargun  Btech     24

# %%
df2[(df2['name']=='Hargun')& (df2['class']=='btech')]
# Out:
# Empty DataFrame
# Columns: [name, class, marks]
# Index: []

# %%
# loc, iloc

# %%
df2.loc[:,:]
# Out:
#      name  class  marks
# 0   Komal  btech     12
# 1  Surbhi  Mtech     14
# 2   Anmol    bca     15
# 3   Rohit    BBA     21
# 4  Hargun  Btech     24
# 5  Jannat    MCA     16

# %%
df2.loc[:,'name']
# Out:
# 0     Komal
# 1    Surbhi
# 2     Anmol
# 3     Rohit
# 4    Hargun
# 5    Jannat
# Name: name, dtype: object

# %%
df2.loc[:,['name','class']]
# Out:
#      name  class
# 0   Komal  btech
# 1  Surbhi  Mtech
# 2   Anmol    bca
# 3   Rohit    BBA
# 4  Hargun  Btech
# 5  Jannat    MCA

# %%
df2.loc[:2,['name']]
# Out:
#      name
# 0   Komal
# 1  Surbhi
# 2   Anmol

# %%
df2.iloc[:,2]
# Out:
# 0    12
# 1    14
# 2    15
# 3    21
# 4    24
# 5    16
# Name: marks, dtype: int64

# %%
df2.iloc[:,:2]
# Out:
#      name  class
# 0   Komal  btech
# 1  Surbhi  Mtech
# 2   Anmol    bca
# 3   Rohit    BBA
# 4  Hargun  Btech
# 5  Jannat    MCA

# %%
df2.loc[2,'name']='Vishal'

# %%
df2
# Out:
#      name  class  marks
# 0   Komal  btech     12
# 1  Surbhi  Mtech     14
# 2  Vishal    bca     15
# 3   Rohit    BBA     21
# 4  Hargun  Btech     24
# 5  Jannat    MCA     16

# %%
df2.loc[:,'rollno']=[11,12,13,14,14,16]
df2
# Out:
#      name  class  marks  rollno
# 0   Komal  btech     12      11
# 1  Surbhi  Mtech     14      12
# 2  Vishal    bca     15      13
# 3   Rohit    BBA     21      14
# 4  Hargun  Btech     24      14
# 5  Jannat    MCA     16      16

# %%
df2.loc[:,'percentage']= (df2.loc[:,'marks']/25) *100

# %%
df2
# Out:
#      name  class  marks  rollno  percentage
# 0   Komal  btech     12      11        48.0
# 1  Surbhi  Mtech     14      12        56.0
# 2  Vishal    bca     15      13        60.0
# 3   Rohit    BBA     21      14        84.0
# 4  Hargun  Btech     24      14        96.0
# 5  Jannat    MCA     16      16        64.0

# %%
df2.drop('rollno', axis=1, inplace=True)  # axis=0  row, axis=1 columns

# %%
df2
# Out:
#      name  class  marks  percentage
# 0   Komal  btech     12        48.0
# 1  Surbhi  Mtech     14        56.0
# 2  Vishal    bca     15        60.0
# 3   Rohit    BBA     21        84.0
# 4  Hargun  Btech     24        96.0
# 5  Jannat    MCA     16        64.0
