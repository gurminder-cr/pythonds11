# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series([20,34,np.nan,60,'hi',np.nan,10,np.nan])
s
# Out:
# 0     20
# 1     34
# 2    NaN
# 3     60
# 4     hi
# 5    NaN
# 6     10
# 7    NaN
# dtype: object

# %%
s.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
s[s.isnull()]
# Out:
# 2    NaN
# 5    NaN
# 7    NaN
# dtype: object

# %%
s[s.isna()]
# Out:
# 2    NaN
# 5    NaN
# 7    NaN
# dtype: object

# %%
s.hasnans
# Out:
# True

# %%
# fill nan values

# %%
s.fillna(2)
# Out:
# 0    20
# 1    34
# 2     2
# 3    60
# 4    hi
# 5     2
# 6    10
# 7     2
# dtype: object

# %%
s1=pd.Series([34,33,21,np.nan])

# %%
s1.fillna(12, inplace=True)

# %%
s1
# Out:
# 0    34.0
# 1    33.0
# 2    21.0
# 3    12.0
# dtype: float64

# %%
age=pd.Series([12,34,56,np.nan,11,57])
age
# Out:
# 0    12.0
# 1    34.0
# 2    56.0
# 3     NaN
# 4    11.0
# 5    57.0
# dtype: float64

# %%
age.fillna(age.mean())
# Out:
# 0    12.0
# 1    34.0
# 2    56.0
# 3    34.0
# 4    11.0
# 5    57.0
# dtype: float64

# %%
product= pd.Series(['Footwear','Accessories','Mens wear','Watches',np.nan,'Footwear','Watches'])

# %%
product
# Out:
# 0       Footwear
# 1    Accessories
# 2      Mens wear
# 3        Watches
# 4            NaN
# 5       Footwear
# 6        Watches
# dtype: object

# %%
product.mode()[0]
# Out:
# 'Footwear'

# %%
product.fillna(product.mode()[0])
# Out:
# 0       Footwear
# 1    Accessories
# 2      Mens wear
# 3        Watches
# 4       Footwear
# 5       Footwear
# 6        Watches
# dtype: object

# %%
s1.min()
# Out:
# 12.0

# %%
s1.max()
# Out:
# 34.0

# %%
s1.describe()
# Out:
# count     4.000000
# mean     25.000000
# std      10.488088
# min      12.000000
# 25%      18.750000
# 50%      27.000000
# 75%      33.250000
# max      34.000000
# dtype: float64

# %%
product
# Out:
# 0       Footwear
# 1    Accessories
# 2      Mens wear
# 3        Watches
# 4            NaN
# 5       Footwear
# 6        Watches
# dtype: object

# %%
product.map({'Footwear':'Shoes','Accessories':1,'Watches':2})
# Out:
# 0    Shoes
# 1        1
# 2      NaN
# 3        2
# 4      NaN
# 5    Shoes
# 6        2
# dtype: object

# %%
s2=pd.Series([34,56,34,78,90,78,56,10])

# %%
s2.unique()
# Out:
# array([34, 56, 78, 90, 10], dtype=int64)

# %%
s2.is_unique
# Out:
# False

# %%
s3=pd.Series([33,45,67])
s3.is_unique
# Out:
# True
