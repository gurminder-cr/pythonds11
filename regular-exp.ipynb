# %%
import regex

# %%
patt='[6-9]{1}\d{9}'
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\hp\AppData\Local\Temp\ipykernel_12812\983770597.py:1: SyntaxWarning: invalid escape sequence '\d'
#   patt='[6-9]{1}\d{9}'

# %%
st='my mobile number is 8264123555 and otehr number is 7696754264 and one more number is 5684546489 and 549849and 5 qnd 4569874562'

# %%
st
# Out:
# 'my mobile number is 8264123555 and otehr number is 7696754264 and one more number is 5684546489 and 549849and 5 qnd 4569874562'

# %%
regex.findall(patt,st)
# Out:
# ['8264123555', '7696754264']

# %%
num= input("Enter Your mobile number ")
ans=regex.match(patt,num)
if ans==None:
    print("Not Valid Number")
# Out:
# Enter Your mobile number  54674654
# Not Valid Number

# %%
mailpatt="[a-zA-Z0-9._]+@[a-zA-Z0-9]+.[a-z]{2,6}"

# %%
st1="email id is gurminder@coderroots.com and other id is coderroots001@gmail.com and one more id is surbhi23@regex.io"

# %%
regex.findall(pattern=mailpatt,string=st1)
# Out:
# ['gurminder@coderroots.com', 'coderroots001@gmail.com', 'surbhi23@regex.io']

# %%
regex.sub(pattern=mailpatt,repl="xyz@gmail.com",string= st1)  # used to replace
# Out:
# 'email id is xyz@gmail.com and other id is xyz@gmail.com and one more id is xyz@gmail.com'
