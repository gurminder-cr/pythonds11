# %%
import pandas as pd

# %%
df=pd.DataFrame({'name':['Komal','Surbhi','Anmol','Rohit','Hargun','Jannat'],'class':['btech','Mtech','bca','BBA','Btech','MCA'],'marks':[12,14,15,21,24,16]})
df
# Out:
#      name  class  marks
# 0   Komal  btech     12
# 1  Surbhi  Mtech     14
# 2   Anmol    bca     15
# 3   Rohit    BBA     21
# 4  Hargun  Btech     24
# 5  Jannat    MCA     16

# %%
df.loc[:,'rollno']=[1,2,3,4,5,6]

# %%
df
# Out:
#      name  class  marks  rollno
# 0   Komal  btech     12       1
# 1  Surbhi  Mtech     14       2
# 2   Anmol    bca     15       3
# 3   Rohit    BBA     21       4
# 4  Hargun  Btech     24       5
# 5  Jannat    MCA     16       6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   class   6 non-null      object
#  2   marks   6 non-null      int64
#  3   rollno  6 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#            marks    rollno
# count   6.000000  6.000000
# mean   17.000000  3.500000
# std     4.560702  1.870829
# min    12.000000  1.000000
# 25%    14.250000  2.250000
# 50%    15.500000  3.500000
# 75%    19.750000  4.750000
# max    24.000000  6.000000

# %%
df
# Out:
#      name  class  marks  rollno
# 0   Komal  btech     12       1
# 1  Surbhi  Mtech     14       2
# 2   Anmol    bca     15       3
# 3   Rohit    BBA     21       4
# 4  Hargun  Btech     24       5
# 5  Jannat    MCA     16       6

# %%
df.insert(loc=2,column='section', value=['A','B','A','C','A','B'])

# %%
df
# Out:
#      name  class section  marks  rollno
# 0   Komal  btech       A     12       1
# 1  Surbhi  Mtech       B     14       2
# 2   Anmol    bca       A     15       3
# 3   Rohit    BBA       C     21       4
# 4  Hargun  Btech       A     24       5
# 5  Jannat    MCA       B     16       6

# %%
df.section.value_counts()
# Out:
# section
# A    3
# B    2
# C    1
# Name: count, dtype: int64

# %%
#group by

# %%
df[df.loc[:,'section']=='A']
# Out:
#      name  class section  marks  rollno
# 0   Komal  btech       A     12       1
# 2   Anmol    bca       A     15       3
# 4  Hargun  Btech       A     24       5

# %%
df.groupby(by='section').get_group('A')
# Out:
#      name  class section  marks  rollno
# 0   Komal  btech       A     12       1
# 2   Anmol    bca       A     15       3
# 4  Hargun  Btech       A     24       5

# %%
df.section=df.section.map({'A':1,'B':2,'C':3})

# %%
df
# Out:
#      name  class  section  marks  rollno
# 0   Komal  btech        1     12       1
# 1  Surbhi  Mtech        2     14       2
# 2   Anmol    bca        1     15       3
# 3   Rohit    BBA        3     21       4
# 4  Hargun  Btech        1     24       5
# 5  Jannat    MCA        2     16       6

# %%
df.rename(columns={'marks':'Numbers'}, inplace=True)

# %%
df
# Out:
#      name  class  section  Numbers  rollno
# 0   Komal  btech        1       12       1
# 1  Surbhi  Mtech        2       14       2
# 2   Anmol    bca        1       15       3
# 3   Rohit    BBA        3       21       4
# 4  Hargun  Btech        1       24       5
# 5  Jannat    MCA        2       16       6
